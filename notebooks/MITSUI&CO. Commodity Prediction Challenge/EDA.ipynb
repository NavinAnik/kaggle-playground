# %%
from utils.download_kaggle_dataset import download_kaggle_competition
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data_set = download_kaggle_competition("mitsui-commodity-prediction-challenge")
print(data_set)
train_df = pd.read_csv(f"{data_set}/train.csv")
train_labels_df = pd.read_csv(f"{data_set}/train_labels.csv")
# Out:
# ...
# Unzipping files...
# Competition data downloaded to: datasets
# datasets

# %%
train_df.head()
# Out:
#    date_id  LME_AH_Close  LME_CA_Close  LME_PB_Close  LME_ZS_Close  \
# 0        0        2264.5        7205.0        2570.0        3349.0
# 1        1        2228.0        7147.0        2579.0        3327.0
# 2        2        2250.0        7188.5        2587.0        3362.0
# 3        3        2202.5        7121.0        2540.0        3354.0
# 4        4        2175.0        7125.0        2604.0        3386.0
#
#    JPX_Gold_Mini_Futures_Open  JPX_Gold_Rolling-Spot_Futures_Open  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                      4684.0                              4691.0
# 3                      4728.0                              4737.0
# 4                         NaN                                 NaN
#
#    JPX_Gold_Standard_Futures_Open  JPX_Platinum_Mini_Futures_Open  \
# 0                             NaN                             NaN
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Columns: 558 entries, date_id to FX_ZARGBP
# dtypes: float64(557), int64(1)
# memory usage: 8.2 MB

# %%
#check for missing values
print(train_df.isnull().sum())
# Out:
# date_id          0
# LME_AH_Close    50
# LME_CA_Close    50
# LME_PB_Close    50
# LME_ZS_Close    50
#                 ..
# FX_NOKGBP        0
# FX_NOKCHF        0
# FX_ZARCHF        0
# FX_NOKJPY        0
# FX_ZARGBP        0
# Length: 558, dtype: int64

# %%
#check for missing values in labels
print(train_labels_df.isnull().sum())
# Out:
# date_id         0
# target_0      130
# target_1      173
# target_2       86
# target_3       86
#              ...
# target_419    102
# target_420    338
# target_421    189
# target_422    218
# target_423    189
# Length: 425, dtype: int64

# %%
#data shapes
print("Train shape:", train_df.shape)
print("Labels shape:", train_labels_df.shape)
# Out:
# Train shape: (1917, 558)
# Labels shape: (1917, 425)

# %%
# Merge train_df with train_labels_df on 'id'
merged_df = pd.merge(train_df, train_labels_df, on='date_id', how='left')

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917 entries, 0 to 1916
# Columns: 982 entries, date_id to target_423
# dtypes: float64(981), int64(1)
# memory usage: 14.4 MB

# %%
merged_df.head()
# Out:
#    date_id  LME_AH_Close  LME_CA_Close  LME_PB_Close  LME_ZS_Close  \
# 0        0        2264.5        7205.0        2570.0        3349.0
# 1        1        2228.0        7147.0        2579.0        3327.0
# 2        2        2250.0        7188.5        2587.0        3362.0
# 3        3        2202.5        7121.0        2540.0        3354.0
# 4        4        2175.0        7125.0        2604.0        3386.0
#
#    JPX_Gold_Mini_Futures_Open  JPX_Gold_Rolling-Spot_Futures_Open  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                      4684.0                              4691.0
# 3                      4728.0                              4737.0
# 4                         NaN                                 NaN
#
#    JPX_Gold_Standard_Futures_Open  JPX_Platinum_Mini_Futures_Open  \
# 0                             NaN                             NaN
# ...

# %%
#plot the distribution of merged_df['label']
plt.figure(figsize=(10, 6))
sns.histplot(merged_df, bins=50, kde=True)
plt.title('Distribution of Labels')
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# /Users/navin/Documents/Anik/GitHub/kaggle-playground/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Correlation matrix
plt.figure(figsize=(12, 10))
corr = merged_df.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
